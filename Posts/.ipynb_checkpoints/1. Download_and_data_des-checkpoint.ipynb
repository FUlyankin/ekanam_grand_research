# %% [markdown]
# <center>
# <img src="https://raw.githubusercontent.com/FUlyankin/ekenam_grand_research/master/images/cover.png">
# </center>
#
#
# # <center> Иканам гранд рисёрч </center>
# ## <center>  Часть первая: собираем данные </center>
#
#
# Проект **Иканам гранд рисёрч** реализуется [Иканам стьюдентс коммьюнити,](https://vk.com/ikanam)
# в частности [вот этим парнем по имени Филипп.](https://vk.com/ppilif) Если вы нашли ошибку или у вас есть предложения, замечания, деньги, слава или женщины, можно ему написать. Весь говнокод, использованный в исследовании распространяется по лицензии [Creative Commons CC BY-NC-SA 4.0.](https://creativecommons.org/licenses/by-nc-sa/4.0/) Его можно использовать в любых целях (редактировать, поправлять и брать за основу), кроме коммерческих, но с обязательным упоминанием автора материала. При наличии технической возможности необходимо также указать активную гиперссылку на [страницу рисёрча.](https://github.com/FUlyankin/ekenam_grand_research)

# %% [markdown]
# # 1. Нефть 21 века
#
# Если вы не угадали, то данные — это нефть 21 века! В этой части исследования мы займёмся их добычей. Обычно, большую часть времени дата-сайнтисты тратят именно на сбор и обработку данных. На моделирование уходит не очень много времени. В нашем исследовании будет три источника данных.
#
# ## 1.1 Приказы с сайта академии и из групп студентов
#
#
# Первый источник — это приказы о зачислении. Их можно найти на сайте академии и в группах студентов. Обычно они идут одним из первых постов.
#
# <img align="center" src="../images/1. data_description/prikaz.png" width="600">
#
# В таких приказах, обычно, указывается в каком году поступил студент, на каких основаниях и с каким баллом за ЕГЭ. Обычно, балл ЕГЭ не указывается у олимпиадников, но у них его можно спросить самостоятельно. Все такие приказы с 2012 по 2017 годы были переработаны в красивые таблички.
#
#
# <img align="center" src="../images/1. data_description/ege_ball.png" width="400">
#
# <br>
#
# В табличках оказались такие переменные как балл за ЕГЭ, проходной балл, год набора, являлся ли человек льготником, целевиком или олимпиадником, фамилия, имя. В конечном итоге в нашем распоряжении окажется $433$ человека.

# %% [markdown]
# ## 1.2 Асессоры
#
# **Всем, кто принял участие в разметке данных, я хотел бы сказать большое спасибо. Без вас нам нечего было бы прогнозировать. Ваши имена никто не узнает. Мало ли нам всем вместе придётся извиняться на камеру.**
#
# К сожалению, приказы об отчислении не лежат в открытом доступе. Поэтому, когда на основе приказов по каждому курсу была подготовлена соответствующая табличка, в дело вступили асессоры. Асессоры — это специально обученные люди, которые занимаются разметкой данных. С каждого курса я попытался выделить три независимые группы асессоров. Каждая группа попыталась вспомнить, а когда же отчислили с факультета каждого конкретного человека, как часто он ходил на пары, как часто ходил на тусы и пытался ли он после отчисления вернуться. Таким образом появилось несколько новых переменных.
#
# <img align="center" src="../images/1. data_description/assessor.png" width="400">

# %% [markdown]
# Переменная kurs ставилась асессорами по шкале от 1 до текущего курса, на котором учится человек. Цифра означает то, с какого курса человек ушёл. Так, например, если человек должен был бы сейчас учиться на третьем курсе, но его выгнали со второго, в графе курс для него будет стоять цифра 2. Если человек уже успешно выпустился с иканама, ему ставилась цифра 5. Обратите внимание на то, что она означает именно то, что человек ушёл с эконома. Чаще всего людей не отчисляют, а дают им возможность перевестиcь. Иногда переводятся люди, которые могли бы потянуть эконом. Тем не менее, по каким-то причинам им у нас не понравилось. Если оставлять в выборке только тех, кого вчистую отчислили, у нас будет очень мало примеров неудач в выборке. Модель в таком случае точно не сможет найти никаких закономерностей. При прогнозах она выдаст то, что все люди в выборке закончат эконом, посчитав, что при таком раскладе её потери будут минимальными. Также в эту переменную входят люди, которые в течение своего обучения собрали дофига пересдач и ушли на пару лет в академ.
# %% [markdown]
# После мы напишем небольшой код, который будет сверять людей из групп с людьми из приказов и при наличии соответствия будет проставлять uid (user id или уид) на страницу человека. После мы попросим асессоров дозаполнять пропуски, а также проверить ссылки на тех, кого наш алгоритм нашёл. В конечном счёте, с контакта мы соберём 706 уникальных юзеров, имеющих отношение к иканаму. По полученному из 706 уидов списку мы и будем собирать данные.
#
# Многие сайты и сервисы хотят упростить жизнь программистам и предоставляют им в пользование уже готовые куски кода, к которым можно просто обратиться и получить нужную информацию о сервисе. Такие куски кода называются API (Application programming interface). Обычно, чтобы подключиться к API, надо создать в соц-сетке своё приложение (как счастливый фермер, но не совсем). Это занимает около 5 минут и даёт тебе ключ доступа.
#
# Вконтакте не является исключением. API Вконтакте это рай для дата-сайентиста. Можно скачать огромное количество всего без серьёзных ограничений, а после заисследовать до потери пульса.
#
# Другие социальные сети ведут себя по отношению к мирным собирателям данных, вроде меня, довольно агрессивно. Например, Facebook по своему API отдаст вам информацию только о тех людях, которые установили ваше приложение.  API Одноклассников потребует написать им письмо с объяснением того, зачем это вам понадобились их данные, а API Вконтакте отдаст вам всё практически задаром. Единственное, что он попросит — это не обращаться к сайту очень часто, и это очень круто.
#
# Тем не менее, недавно Вконтакте провёл серьёзную реформу своей музыкальной части и монетизировал её. Это привело к изъятию куска API, связанного с музыкой из открытого доступа. Более того, существует опасность, что социальная сеть продолжит резать бесплатный функционал своего API после разных скандалов, связанных с банками, нагло собирающими информацию о пользователях для своих скоринговых моделей. Это означает, что надо накачать данных и успеть наисследоваться вдоволь.

# %% [markdown]
# ### 1.3.1 Данные о профиле
#
# Всегда, когда скачиваете данные, сохраняйте их в черновом виде, и уже только после этого обрабатывайте. В ходе обработки будут происходить непредвиденные ситуации и многие вещи придётся переделывать. Сначала будем сохранять грязные данные. В том числе и бесполезные переменные. Позже, когда мы будем перерабатывать данные в модельный вид, от всей чернухи мы избавимся.
#
# Итак, скачаем по каждому иканамовцу всё, что только можно скачать. Дату рождения, город, пол, состоит ли он в отношениях.
#
# <img align="center" src="../images/1. data_description/1.scr_table_1.jpg" width="800">
#
# Также скачаем информацию о том какую именно активность предпочитает человек, что написано у него в профиле, есть ли ссылки на какие-то другие сервисы вродe facebook и так далее.
#
# <img align="center" src="../images/1. data_description/1.scr_table_2.png" width="900">
#
# Уже на этом этапе можно заметить две важные особенности:
#
# 1. Многие люди из ряда вон плохо заполняют свои профили. Кто-то не указывает свою религию, кто-то свои любимые фильмы. Все эти переменные нам в конечном итоге придётся выбросить. Погоды по ним не сделаешь.
# 2. Читаю книжки, сижу на мужских шишках. Серьёзно? Бьюсь об заклад, что этот парень подписан на мусорные паблики вроде MDK, но о пабликах речь пойдёт ниже.
#
# Конечно же не обойдётся без скачки информации о том как человек относится к алкоголю, информации о количестве фоток, подарков, друзей, подписчиков, религии, политических предпочтений и многого другого.
#
# <img align="center" src="../images/1. data_description/1 scr_table_3.png" width="900">
#
# Все данные по профилям лежат в табличке с гордым именем `vk_data_profile_дата_скачки.csv`.

# %% [markdown]
# ### 1.3.2 Аватарки
#
# Отдельно скачаем всю информацию по аватаркам. По ним можно вытащить ссылку на фоточку, её размеры, а также инфу о том как именно человек обрeзал фотку, когда ставил её на аву.  Эта информация лежит в файле `vk_data_photos_дата_скачки.pickle`. Pickle это не огурчик, это специальный формат для хранения данных. :)
#
# ### 1.3.3 Паблики
#
# После скачаем инфу о том кто и на какие паблики подписан. Она лежит в файле `vk_data_group_дата_скачки.pickle` в виде словарика
#
# ```
# {uid : вектор из пабликов, на которые подписан uid}
# ```
#
# С авками и пабликами мы будем работать отдельно. Для пабликов мы попытаемся применить такую страшную штуку, как тематическое моделирование. Оно поможет нам разделить паблики на несколько разных групп по их тематикам. Это будет политика, мемы и многое другое. Фоточки мы попробуем загнать в нейросетки.

# %% [markdown]
# ### 1.3.4  Стены юзеров и фотки из альбомов
#
# Стенки и фотки — это огромное море контента. Интересно будет узнать что именно репостят люди, что выкладывают и как лайкают. Стенки скачаем в двух видах. В грязном виде стенки будут выглядеть вот так:
#
# <img align="center" src="../images/1. data_description/1 scr_table_wall.png" width="900">
#
# Дата поста, контент этого поста, чей это пост, репостнут ли он, с какого устройства был сделан этот пост (iphone, android и тп). Можно будет оценить примерную долю яблочников на экономе, а также найти тех, кто совершает против человечества преступления (пользуется windows phone).
#
# На основе таких грязных стен мы попробуем выделить по каждому человеку интересные переменные. Например, эмодзи-след человека, среднее количество слов в посте, максимальное количествос слов в посте, в скольки постах встречаются фотки, музыка и так далее.
#
# Грязные стены в виде словариков лежат в файле `vk_dirty_wall_дата_скачки.pickle`. Все посты всего иканама в виде таблички лежат в файле `vk_dirty_wall_data_дата_скачки.csv`. Стены переработанные в итоговые, интересующие нас переменные, лежат в табличке `vk_wall_data_дата_скачки.csv`
#
# С фотками мы поступим аналогично. На выход пойдёт три таблички. `vk_dirty_photo_дата_скачки.pickle`, `vk_dirty_photo_data_дата_скачки.csv`, `vk_photo_data_дата_скачки.csv`.
#
# ### 1.3.5 Лайки
#
# Осталось самое главное и ресурсоёмкое. Лайки.  Для начала мы скачаем все лайки, которые стоят под фотками и все лайки, которые стоят под постами для каждого юзера.  Мы скачаем все лайки под постами на стене в файл `vk_total_wal_likes_дата_скачки.pickle` в виде `{дата поста : uid пользователей, который лайкнули пост}`. Лайки под фотками сохраним в файл `'vk_total_photo_likes_дата_cкачки.pikcle` в аналогичном формате.
#
# <img align="center" src="../images/1. data_description/1 scr wall_like.png" width="450">
#
# ### 1.3.6 Паблики
#
# Чуть позже, когда до этого дойдут руки, мы скачаем из тех пабликов, на которые подписан иканам по 100 самых свежих постов, а также лайки под каждым из этих постов. Все паблики, которые окажустся в наших рисёрческих руках, мы попробуем раздробить по разным темам с помощью специальной модели. Данные по темам мы добавим в основную выборку.

# %% [markdown]
# ## Хмммм...
#
# Когда я писал код для скачки всего этого добра и туториал по этому коду, я и подумать не мог, что описание данных займёт так мало места, ибо код для скачки получился довольно внушительным. Впереди нас ждёт более пристальная работа с накаченным добром. Если есть желание понять как именно происходит скачка данных из контакта, советую прочитать [туториал об этом.](http://nbviewer.jupyter.org/github/FUlyankin/ekanam_grand_research/blob/master/0.%20vk_parser_tutorial.ipynb)  Часть, которая связана с графом, скопипащена в этот туториал из главы рисёрча про графы. Единственное, из неё удалена работа с алгоритмами. Уже после можно посмотреть сам по себе [код, которым скачивался иканам.](http://nbviewer.jupyter.org/github/FUlyankin/ekanam_grand_research/blob/master/1.Download_vk_data/1.%20ikanam_save_data.ipynb)
#
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/Parsers/master/images%20/cats.jpg" height="1200" width="1200">
