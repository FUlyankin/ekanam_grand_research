# %% [markdown]
# <center>
# <img src="https://raw.githubusercontent.com/FUlyankin/ekenam_grand_research/master/images/cover.png">
# </center>
#
#
# # <center> Иканам гранд рисёрч </center>
# ## <center>  Часть третья: Паблики. Исследуем тематики пабликов. </center>
#
#
# Проект **Иканам гранд рисёрч** реализуется [Иканам стьюдентс коммьюнити,](https://vk.com/ikanam)
# в частности [вот этим парнем по имени Филипп.](https://vk.com/ppilif)  Если вы нашли ошибку или у вас есть предложения, замечания, деньги, слава или женщины, можно ему написать. Весь говнокод, использованный в исследовании распостраняется по лицензии [Creative Commons CC BY-NC-SA 4.0.](https://creativecommons.org/licenses/by-nc-sa/4.0/) Его можно использовать в любых целях (редактировать, поправлять и брать за основу), кроме коммерческих, но с обязательным упоминанием автора материала. При наличии технической возможности необходимо также указать активную гиперссылку на [страницу рисёрча.](https://github.com/FUlyankin/ekenam_grand_research)

# %% [markdown]
# # 1. А ты в теме?
#
# Итак, в предыдущей части мы выделили темы, которые встречаются в подписках у эконома. Мы попробовали проинтерпретировать эти темы. В конечном счёте мы получили слудующий список:
#
# ```
#  0 : 'концерт, фестиваль',  1 : 'мода, одежда',      2 : 'поездки, путишествия',  3 : 'тренировки',
#  4 : 'рецепты, еда',        5 : 'мусор-1',           6 : 'квалификация, тренинг', 7 : 'интернет, девайсы',
#  8 : 'торговля, реклама',   9 : 'мусор-2',           10: 'телек, спорт, сериалы', 11: 'машины',
#  12: 'бизнес, стартапы',    13: 'ваниль, чувства, пафос',  14: 'языки',           15: 'самобытность, история',
#  16: 'фото, кастинги',      17: 'мемы',              18: 'искусство',             19: 'мусор-3',
#  20: 'кино, мусор-4',       21: 'тело, красота',     22: 'музыка',                23: 'нерусские группы',
#  24: 'украина, мусор-5',    25: 'студенты, вузы',    26: 'мемы, дота, игры',     27: 'подслушано, анон, курсач',
#  28: 'новости, государство',29: 'ислам'
# ```
#
# Ещё раз обратите внимание на важный момент: название темы не в полной мере отображает её суть. Для того, чтобы прочувствовать выделившуюся тему, нужно взглянуть на её ключевые слова и группы. В этой части мы попытаемся понять:
#
# * Какие темы наиболее популярны на экономе
# * В какие темы вкладывается наибольшее число лайков
# * Какие паблики люди лайкают, но при этом на них не подписываются
#
# Для начала посмотрим на то, насколько темы, постоенные нами, [коррелируют](https://ru.wikipedia.org/wiki/Корреляция) между собой.
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/ekanam_grand_research/master/images/3.%20publics/pub_corr_30.png" width="700">
#
# Как можно увидеть, темы не коррелируют друг с другом особо сильно. Самая большая корреляция $0.5$ находится на пересечении тем "чувства, ваниль" и "тело и красота". Это означает, что люди, интересующиеся ванилью и чувствами часто попутно интересуются телом и красотой. Наверное, это неудивительно...

# %% [markdown]
# # 2.  Тематические профили
#
# Итак, у каждого человека в подписках есть паблики. У каждого паблика есть темы. Давайте возьмём конкретного человека. Предположим, что он подписан на три паблика. Предположим, что паблики имеют следующую тематическую структуру:
#
# ```
#                         паблик 1:  {тема 1 : 0.5, тема 2 : 0.5}
#                         паблик 2:  {тема 2 : 0.5, тема 3 : 0.5}
#                         паблик 3:  {тема 2 : 0.2, тема 3 : 0.4, тема 4 : 0.4}
#
# ```
#
# Такая тематическая структура означает, что контент первого паблика на 50% состоит из первой темы и на 50% из второй темы. Контент второго на 50% из второй и 50% из третьей, контент третьего паблика состоит из трёх тем. Такие доли нам выдал наш алгоритм кластеризации, описаный в предыдущей почиташке.
#
# Если мы проагрегируем все темы и соответствующие им доли, мы получим **тематический профиль человека.** Для рассматриваемого примера, мы можем сделать это следующим образом.
#
# ```
#                 Относительная доля первой темы в подписках:  (0.5 + 0 + 0)/3 = 0.17
#
#                 Относительная доля второй темы в подписках:  (0.5 + 0.5 + 0.2)/3 = 0.4
#
#                 Относительная доля третьей темы в подписках: (0 + 0.5 + 0.4)/3 = 0.3
#
#                 Относительная доля четвёртой темы в подписках: (0 + 0 + 0.4)/3 = 0.13
#
# ```
#
# Все веса отнормированы на число документов. Полученую цифру можно интерпретировать как вероятность встретить эту тему в подписках у человека. Попробуем построить тематический профиль для ~~какого-нибудь случайного человека~~  Саши Тишина.
#
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/ekanam_grand_research/master/images/3.%20publics/Sasha_profile.png" width="1100">

# %% [markdown]
# **Ещё раз, ещё раз.** Обратите внимание на то, что названия тем приведены здесь для удобства и краткости и переодически не отображают тот контент, который находится в группе. Когда мы смотрим на тематический профиль человека, в первую очередь необходимо смотреть не на название темы, а на её ключевые слова. Проанализируем чуть более подробно то, какие именно группы вностят в разные темы Сашиного профиля свой вклад.
#
# Например, **тема искусство** складывалась, в основном, из групп:
#
# ```
#  ('Театр. Книги.', 0.69687223),
#  ('Art Traffic. Культура. Искусство', 0.68292743),
#  ('Музей современного искусства «Гараж»', 0.56140447),
#  ('О фотографии', 0.53545946),
#  ('Горький. О книгах и чтении', 0.52829945),
#  ('Arzamas', 0.5153411),
#  ('Artplay Media', 0.51434034),
#  ('АРТГИД \\ ARTGUIDE', 0.49237734),
#  ('Электротеатр Станиславский', 0.46669069),
#  ('The Art Newspaper Russia', 0.4606472),
#  ('ВИНЗАВОД. ЦЕНТР СОВРЕМЕННОГО ИСКУССТВА', 0.37276232),
#  ('Современный театр', 0.36171284),
#  ('Петербургская Филармония им. Шостаковича', 0.33985457),
#  ('Лучшие видеолекции', 0.33459136),
#  ('The Met: Live in HD (Россия)', 0.29505265),
#  ('Deep Space', 0.28223938),
#  ('E:\\music\\neoclassical', 0.25870413)
#
# ```
#
# В списке приводится название группы и то какую долю в этой группе занимает тема искусство. Еще раз обращаю ваше внимание на то, что наш алгоритм выделял в каждой группе несколько тем. В принципе, группы, которые делают свой вклад в тему искусство, выглядят довольно логично. Группы, которые формируют **тему квалификация, тренинг** также выглядят вполне логично.
#
# ```
# ('FinExecutive', 0.76686192),
#  ('NES Banking &amp; Finance Society', 0.66312921),
#  ('Plekhanov Investment Banking Club', 0.63982421),
#  ('Московская Биржа', 0.58805311),
#  ('Societe Financiers | SF', 0.56195182),
#  ('Bain &amp; Company', 0.55065441),
#  ('Collapse', 0.53798908),
#  ('MGIMO Case Club | Кейс-клуб МГИМО', 0.51709759),
#  ('ЦМФ', 0.50469315),
#  ('Management Consulting Club', 0.49511254),
#  ('Экономика РФ', 0.45599663),
#  ('UpGrade', 0.40175205),
#  ('The Foundation', 0.35009587),
#  ('McKinsey Business Diving 2017', 0.34565735),
#  ('Фонд Первое Поколение', 0.28103209),
#  ('Тинькофф Банк', 0.24575067),
#  ('Epistemia', 0.2286188),
#  ('Национальная платформа открытого образования', 0.22843872)
# ```
#
# Логичный результат получается для любой темы, которая в профиле человека представлена в довольно большом объёме. Однако если тема представлена с маленькой долей, начинают выскакивать шумы. Например, для **темы тренировки**, выскакивают следущие группы:
#
# ```
#  ('Deep Space', 0.20993723),
#  ('Плохие идеи для рисёча', 0.078124672),
#  ('Современный театр', 0.065100759),
#  ('Epistemia', 0.046843365),
#  ('Курилка ЦэБэ', 0.033333335),
#  ('Вопросы игры Что? Где? Когда?', 0.023156945),
#  ('Лучшие видеолекции', 0.017007248),
#  ('Deep|Bayes', 0.015882483),
#  ('Шедевры фотографии - Фотографы и модели', 0.0157171),
#  ('Внешний Вид', 0.0144171),
#  ('Универсиада по эконометрике', 0.012770025),
#  ('Иван Фефелов | стихи', 0.012129759),
#  ('Хабрахабр', 0.012046883),
#  ('Gravity Falls | Гравити Фолз', 0.01111043),
#  ('стихи Сопрано', 0.010653907),
#  ('I Like Trip Клуб путешествий ВШЭ и МФТИ', 0.010610334),
#  ('Исчисляй', 0.010017959)
# ```
#
#
# ```
# Ключевые слова для темы тренировки :
# пулловер, мышцы, тренировки, стёганый, упражнения, тела, ноги, мышц, организм, организма, упражнение, следует, крови, воды, системы, тренировок, питания, уровень, пищи, упражнений
# ```
#
# В каждой из выскачивших групп, тренировочная тема, занимает довольно маленькую долю. Скорее всего, в контенте группы встречались какие-то слова из тренировочной темы в нетренировочном контектсте и из-за этого алгоритм уделил тематике в группе какой-то небольшой вес. Можно попробовать исправить эту проблемы и добиться зануления подобных тем. Для этого мы должны будем добавть при обучении к нашему алгоритму специальный регуляризатор. Если у вас есть желание получить идеально интерпретируемый кластеризатор, можете заняться этим на досуге.
#
# В связи с описанной выше проблемой, имеет смысл смотреть только на топ тем. Также имеет смысл смотреть не только на их названия, но и на ключевые слова.  Подобные тематические профили для каждого человека, попавшего в выборку, можно будет увидеть в специально заготовленной визуализашке, ссылку на которую можна найти в карте рисёрча.

# %% [markdown]
# # 3. Близкие по духу
#
# Каждый тематические профиль - это вектор из 30 чисел. Можно попробовать искать между этими векторам расстояния и найти похожих друг на друга людей. Если расстояние между векторами, описывающими профили людей, маленькое, значит люди похожи. Вопрос только в том какую метрику для поиска расстояния можно было бы использовать в нашей ситуации.
#
# Мы попробуем использовать несколько расстояний. Первыи из них будет обычное, евклидово расстояние, знакомое нам со школы:
#
# $$ \rho(x,y) = \sqrt{ (y_1 - x_1)^2 + \ldots + (y_n - x_n)^2} $$
#
# Одна из особенностей наших тематических профилей состоит в том, что они довольно сильно разряжены. Более того, доли, которые входят в них, довольно низки. Из-за этого все, вычисленные нами евклидовы расстояния окажутся довольно маленькими и похожими. Мы попробуем немного выправить эту проблему с помощью косинусной меры:
#
# $$ \rho(x,y) = 1 - \cos(x,y) $$
#
# Косинусная мера часто используется для измерения схожести между текстами. Как мы уже выяснили в прошлый раз, каждый документ описывается вектором, каждая компонента которого соответствует слову из словаря. Компонента равна единице, если соответствующее слово встречается в тексте, и нулю в противном случае. Обычно, эти вектора очень сильно разряжены (содержут огромное число нулей). Косинус между двумя векторами будет тем больше, чем больше слов встречаются в этих двух документах одновременно. В нашей ситуации, косинус между двумся векторами будет тем больше, чем больше у нас схожих тематик.

# %% [markdown]
# При изучениее так называемых "похожих" людей, обратите внимание на то, что отличие в расстояниях в топе довольно маленькие. Также обратите внимание на то, что из-за маленького числа подписок иногда возникают шумы. Человек был подписан на один паблик, его тематический профиль определился по одному паблику и он вышел на вас похожим. Возможно, одним из направлений доработки похожести людей, может стать нормировка всех найденных расстояний на число пабликов.
#
#
# Итак, самые похожие на экономе люди. В скобках приведено расстояние. По косинусному расстоянию:
#
# ```
# 1. Исхакова Фарида и Сидорук Дарья             (0.01079)
# 2. Петрова Диана и Mirzayanov Ilnaz            (0.01085)
# 3. Полякова Александра и Макагонова Татьяна    (0.01446)
# 4. Брянцева Мария и Khurtina Katya             (0.01496)
# 5. Голубева Танюшка и Семедова Наиля           (0.01569)
# ```
#
#
# По еквклидовому расстоянию:
#
# ```
# 1. Полякова Александра и Макагонова Татьяна    (0.04831)
# 2. Джигкаев Георгий и Hasan Abas               (0.04942)
# 3. Исхакова Фарида и Сидорук Дарья             (0.04944)
# 4. Кристя Кристина и Макагонова Татьяна        (0.05245)
# 5. Дзюба Артём и Мухин Тимофей                 (0.05287)
#
# ```
#
# Топы получились похожими. Насколько близки люди в них, наверное, имеет смысл судить этим людям. Попробуем найти самых близких по интересам людей к Диане.
#
# ```
# 0.01 Mirzayanov Ilnaz
# 0.05 Потапова Мария
# 0.07 Голованова Лиза
# 0.08 Okonor Brayan
# 0.1 Данильченко Леонид
# 0.1 Ульянкин Филипп
# 0.1 Малышев Яша
# 0.12 Россошанский Алексей
# 0.13 Зюзько Кристина
# 0.15 Фёдоров Артур
# 0.15 Царёв Алексей
# 0.15 Коннова Анастасия
# 0.18 Шакуров Тимур
# 0.19 Гайнулина Алина
# 0.19 Шелякин Антон
# ```
#
# Также можно найти людей, похожих на Таню:
#
# ```
# 0.01 Полякова Александра
# 0.02 Кристя Кристина
# 0.02 Самотканова Виктория
# 0.03 Ахметзянова Дарья
# 0.03 Евдокимова Алина
# 0.03 Сакович Дарья
# 0.03 Буханцев Никита
# 0.03 Беляева Елена
# 0.03 Анискина Лера
# 0.03 Аксенова Аня
# 0.03 Гришкина Катя
# 0.03 Бубен Валерия
# 0.04 Казарян Диана
# 0.04 Мм Ааа
# 0.04 Ponkina Daria
# ```
#
# Ну или людей, похожих на меня.
#
# ```
# 0.04 Данильченко Леонид
# 0.06 Потапова Мария
# 0.07 Mirzayanov Ilnaz
# 0.07 Малышев Яша
# 0.08 Шелякин Антон
# 0.09 Голованова Лиза
# 0.09 Осипов Сергей
# 0.1 Россошанский Алексей
# 0.1 Петрова Диана
# 0.11 Евстафьев Сергей
# 0.11 Pervin Pervin
# 0.11 Кожевников Егор
# 0.12 Царёв Алексей
# 0.12 Фоломеев Александр
# 0.13 Pereboykina Katerina
# ```
#
#
# **Ещё раз ещё раз.** Мы только что попробовали использовать подписки человека в качестве инструмента для ненаблюдаемой переменной интересы. С помощью этого инструмента мы попробовали найти близких друг к другу по интересам людей. В моём списке я вижу людей, интересы которых, действительно совпадают с моими. Рассмотренную методологию выявления близких по интересам людей можно улучшить в следующих направлениях:
#
# 1. Сделать кластеризацию по тематикам более чёткой.
# 2. У многих людей в подписках куча мусорных пабликов, которые зашумляют их тематический профиль. Имеет смысл попробовать взять только те паблики, которые находятся у людей в топе списка. Обычно наверху находятся те страницы, которые человек наиболее часто посещает.
#
# После проработке всех промахов и недочётов можно смело пилить приложение для поиска жены или мужа. Я верю, что можно сделать из этого конфетку. Вы можете попробовать найти похожих на вас людей во всё той же визуализашке, ссылка на которую есть в карте рисёрча.

# %% [markdown]
# # 4. Тематические профиль эконома
#
# Проагрегируем тематические топы по всем людям и посмотрим что у нас получится.
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/ekanam_grand_research/master/images/3.%20publics/ekanam_prof.png" width="1100">

# %% [markdown]
# В принципе, можно построить аналогичные топы по всем курсам по очереди и посмотреть что происходит для них, но разницы между ними особой не будет.

# %% [markdown]
# # 5. Лайк-топы
#
# Построим очередную матрицу лайков. На этот раз будем откладывать по строкам пользователей, по столбцам группы. На месте $(i,j)$ будет стоять число лайков, которое юзер $i$ оставил группе $j$. В конечном счёте матрица выйдет довольно большой. По аналогии построим матрицу подписок. Если на месте $(i,j)$ стоит единичка, значит юзер $i$ подписался на группу $j$.
#
# Матрица будет строится 18 часов. Когда её строительство завершится, мы сможем посмотерть на несколько лайк-топов.
#
#
# ## 5.1 Самые популярные группы
#
# Попробуем построить рейтинг с самыми популярными группами. В очередной раз напомню, что в анализ берутся последние 100 постов из каждой группы, а также что матрица лайков строилась 18 часов. Напоминаю я это в связи со своей ошибкой.
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/ekanam_grand_research/master/images/3.%20publics/most_popular.png" width="1500">
#
# Мы, конструируя данный рейтинг совершили две ошибки. Вы, как эксперты по анализу лайков, уже знакомые с f-мерой и дисконтированными лайками, легко можете догадаться какие именно.
#
# 1. Иногда бывает так, что какой-нибудь безумный чувак, лайкает все цитаты паблика подряд. Имеет смысл поделить число лайков, которое оставил каждый человек на максимальное количество оставленных им лайков. В прошлый раз мы называли такие лайки дисконтированными.
# 2. Неплохо было бы учитывать, что некоторые паблики делают посты довольно часто, а некоторые довольно редко. В словаре с лайками есть даты постов и их можно было бы использовать при расчёте времени, которое прошло между постами. Однако матрица строилась 18 часов и я не хочу опять перезапускать её построение. Если вам интересно посмотреть как влияет корректировка на частоту постов на популярность паблика, не забудьте поделиться результатами своего рисёрча.
#
# Итак, попробуем построить точно такой же рейтинг на основе дисконтированных лайков.
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/ekanam_grand_research/master/images/3.%20publics/discont_most_popular.png" width="1500">

# %% [markdown]
# Перваки слишком сильно любят свой паблик. Даже дисконтирование не выкинуло его из топа... Отдельно отмечу, что приятно видеть, что всякие паблики вроде академия тудэй и тп не получают лайков чуть более, чем совсем. Друзья, если они генерируют плохой контент, который не достоин вашего лайка, наверное, имеет смысл отписаться от них. Навсегда. Да. Студпассив.
#
# ## 5.2 Лайкают паблики больше всех
#
# Посмотрим на людей, которые лайкают паблики больше всего.
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/ekanam_grand_research/master/images/3.%20publics//people_most_like.png" width="1500">
#
# Возможно, что между тем как часто человек лайкает паблики и его успеваемостью есть корреляция. Люди, оставляющие вк много лайков, явно тратят на социальную сетку много времени. Нужно будет попробовать добавить такую переменную в модель.
#
# **Update для своих:** Прогнозы, которые висят в группе, построены без участия этой переменной. Это свежая идея, о результативности которой можно узнать в одной из следующих почиташек.

# %% [markdown]
# ## 5.3 Лайкают, но не подписываются
#
# Посмотрим на группы, которые лайкают, но не подписываются и на людей, которые этим занимаются.
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/ekanam_grand_research/master/images/3.%20publics/like_not_dis.png" width="1500">
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/ekanam_grand_research/master/images/3.%20publics/like_notdis_ppl.png" width="1500">
#
# Ничего особо интересного... Не очень приятно видеть себя в подобных рейтингах. Надо меньше сидеть вконтакте.

# %% [markdown]
# ## 5.4 Индивидуальные рейтинги
#
# Попробуем построить индивидуальные лайк-топы для групп и для юзеров. Обратите ещё раз внимание на то, что в исследовании собрана не вся история всех $20000$ пабликов, а лишь последние 100 постов из каждого. При таком подходе к исследованию, можно худо-бедно выявить самые популярные паблики для сообщества в целом.
#
# Для отдельного человека ошибка будет довольно высокой, так как для многих частопостящих пабликов, $100$ последних постов явно мало. Если вас интересует какой-то конкретный человек и топ его лайков, имеет смысл написать код, который будет проходиться по всем постам во всех пабликах и проверять наличие лайка только для этого пользователя. По идее, в течение суток, такой код справится с обходом.
#
# В нашей ситуации индивидуальные топы будут выглядеть не очень адеватно.
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/ekanam_grand_research/master/images/3.%20publics/Ira_top.png" width="1300">

# %% [markdown]
# ## 6. Популярность выделенных тематик
#
# Посмотрим на то какие из выделенных тематик наиболее популярны на экономе. Для этого будем умножать число лайков, поставленное в группу на вероятность встретить в ней текущую тему.
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/ekanam_grand_research/master/images/3.%20publics/themes_pop.png" width="1500">
#
# В очередной раз напомню, что тема "ваниль, чувства, пафос" это всего лишь название темы. Тем не менее, термины, которые эти темы наполняют, лично мне не говорят ничего хорошего. Лишний раз продублирую слова, которые характеризуют первые пять тем, а также группы, характеризующие их:

# %% [markdown]
# **Ваниль, чувства, пафос:**
#
# 'женщина, женщины, отношения, любить, мужчина, тобой, однажды, чувство, мужчины, можешь, человеком, женщин, человеку, чувства, будь, тело, боль, твой, думать, читать, будешь, любят, ребенка, чему, страх, другого, плохо, твоя, радость, мечты'
#
# ```
# ['Омар Хайям и другие великие философы',
#  'morfin.',
#  'Реальность',
#  'Факты о родившихся 28 мая',
#  'Цепляет',
#  'Как-то похер.',
#  'Pyramid',
#  'Пауло Коэльо и другие',
#  '5 умных мыслей',
#  'FRIDAY.',
#  'M Ø R P H I N Σ',
#  'Статусы Со Смыслом',
#  'Современная Философия',
#  'вместе навсегда',
#  'Yes']
# ```
#
# **Мемы:**
#
# 'мама, говно, знаешь, папа, родители, домой, парень, начал, доме, твои, девушка, общем, пишет, вроде, нахуй, поняли, голова, живет, понял, паблика, отсюда, сказала, целую, каждая, подписчиков, игра, наверное, детям, получила, лайки'
#
# ```
# 'ИнстаХлам',
#  'Пьяный Единорог',
#  'HIGH SCHOOL',
#  'ВыЖеРодители',
#  'Улётные приколы',
#  '4ch',
#  'Live In Tattoo | Татуировки',
#  'П Ё С Ь К А',
#  'Безысходность',
#  'ПОШЁЛ НАХУЙ КАЖДЫЙ ДЕНЬ.',
#  'ᴠɪᴅᴇᴏsos',
#  'Live In Art | Искусство',
#  'Ответ по Фрейду',
#  '💥Фанфа про Святослава💥👼',
#  'Упоротый Единорог'
# ```
#
#
# **Концерт, фестиваль:**
#
# 'вход, билеты, мастер, ждем, москвы, концерт, адрес, санкт, приходите, праздник, стоимость, подарки, фестиваль, новогодние, метро, подробнее, сентября, фестиваля, состоится, билет, поздравляем, гостей, конкурс, конкурса, воскресенье, выходные, запись, билетов, новогодний, театр'
#
#
# ```
# 'Relax Art ™',
#  'S.O.V.A. - #ГЛАЗАОТКРОЙ',
#  'Афиша Нижневартовска',
#  'Свободное Пространство «ТИПИЧНЫЙ ПИТЕР» Антикафе',
#  'у ю т н о с т ь',
#  'КРЫША — ЛОФТ ПРОЕКТ ЭТАЖИ',
#  'Каток в городском парке Орехово-Зуево',
#  'FreeShows - бесплатные события Москвы',
#  'черный файл',
#  'Как такое возможно?',
#  'КУРИЛЫ (ВДНХ)',
#  'Мой Питер | Санкт-Петербург',
#  'ТРЦ РИО "Кострома"',
#  'Научное шоу ОТКРЫВАШКА в Санкт-Петербурге',
#  'Фестивали Москвы'
# ```
#
#
# **Студенты, вузы:**
#
# 'студентов, студенты, состоится, регистрация, университета, программы, обучения, развития, российской, факультета, образования, ранхигс, мероприятия, школы, курса, участники, федерации, апреля, курс, института, сентября, пройдет, конкурса, мероприятие, конференции, проведения, конкурс, команды, управления, организации'
#
# ```
# 'Дистанционные курсы повышения квалификации',
#  'Курсы повышения квалификации 2018',
#  'Курсы повышения квалификации для педагогов',
#  'Курсы повышения квалификации для учителей',
#  'Курсы повышения квалификации для воспитателей',
#  'Курсы повышения квалификации',
#  '"Учебный центр повышения квалификации АПК РТ"',
#  'Кадровый портал Ленинградской области',
#  'Институт переподготовки и повышения квалификации',
#  'Аттестация рабочих мест, повышение квалификации',
#  'Российская академия народного хозяйства',
#  'Кумертауский институт экономики и права',
#  'Центр Непрерывного Образования (ЦНО)',
#  'Московский Социально - Гуманитарный Институт',
#  'Кадровый портал Администрации Санкт-Петербурга'
# ```
#
#
# **Бизнес, стартапы:**
#
# 'бизнес, бизнеса, цели, брэнды, клиентов, будете, цель, идея, правило, результат, идеи, успеха, брэндов, план, способ, процесс, решения, информацию, уровень, заниматься, следует, большинство, книга, стоимость, зависит, создать, целей, вариант, ситуации, производства'
#
# ```
# 'tumblr salad shop/шмот на алиэкспресс',
#  'Маркетинговое Агентство "Группа-АБ"',
#  'Российская академия автомобильного бизнеса.',
#  'Советские плакаты',
#  'Акселератор онлайн-школ',
#  'Wiki Business - бизнес, стартап',
#  'Zeitgeist 00',
#  'Кружка кофе',
#  'РОСТ ВСЕМ! бизнес коучинг',
#  'Бизнес клуб',
#  'ДОСКА ОБЪЯВЛЕНИЙ | ОБЪЯВЛЕНИЯ В САНКТ-ПЕТЕРБУРГЕ',
#  'Black Lion | Бизнес Журнал',
#  'Клуб "Свое дело" – Идеи. Технологии. Тренинги.',
#  'Механика бизнеса',
#  'Стартап | Идеи для бизнеса'
# ```

# %% [markdown]
# Покачто на этом всё. Увидимся в следующей части, в которой мы займёмся достижением нашей последней цели.
#
# <img align="center" src="https://raw.githubusercontent.com/FUlyankin/Parsers/master/images%20/cats.jpg" height="1200" width="1200">
